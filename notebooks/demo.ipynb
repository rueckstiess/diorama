# %% [markdown]
# # Diorama Demo
#
# Interactive 2D/3D embedding visualization for JSON documents.

# %%
import numpy as np

import diorama

# %% [markdown]
# ## Load data

# %%
npz = np.load("../electric_vehicles.npz", allow_pickle=True)
documents = list(npz["data"])[:100000]
embeddings = npz["embs"][:100000]

print(f"{len(documents)} documents, {embeddings.shape[1]}-dim embeddings")
documents[0]
# Out:
# 100000 documents, 64-dim embeddings
# {'Record Type': 'VEH',
#  'Registration Class': 'PAS',
#  'City': 'POINT LOOKOUT',
#  'State': 'NY',
#  'Zip': '11569',
#  'County': 'NASSAU',
#  'Model Year': 2026,
#  'Make': 'HYUND',
#  'Body Type': 'SUBN',
#  'Unladen Weight': 6008,
#  'Maximum Gross Weight': None,
#  'Passengers': None,
#  'Color': 'BK',
#  'Scofflaw Indicator': 'N',
#  'Suspension Indicator': 'N',
#  'Revocation Indicator': 'N'}

# %% [markdown]
# ## Reduce once, explore fast
#
# UMAP is the expensive step. Run it once and reuse the result.

# %%
reduced_2d = diorama.reduce(embeddings, n_components=2, method="umap", subsample=10_000, show_progress=True)
reduced_3d = diorama.reduce(embeddings, n_components=3, method="umap", subsample=10_000, show_progress=True)

print(f"2D: {reduced_2d.shape}, 3D: {reduced_3d.shape}")
# Out:
# UMAP(angular_rp_forest=True, metric='cosine', verbose=True)
# Thu Feb 12 20:24:05 2026 Construct fuzzy simplicial set
# Thu Feb 12 20:24:05 2026 Finding Nearest Neighbors
# Thu Feb 12 20:24:05 2026 Building RP forest with 21 trees
# Thu Feb 12 20:24:05 2026 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	Stopping threshold met -- exiting after 3 iterations
# Thu Feb 12 20:24:06 2026 Finished Nearest Neighbor Search
# Thu Feb 12 20:24:06 2026 Construct embedding
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 reduced_2d = diorama.reduce(embeddings, n_components=2, method="umap", show_progress=True)
#       2 reduced_3d = diorama.reduce(embeddings, n_components=3, method="umap", show_progress=True)
#       4 print(f"2D: {reduced_2d.shape}, 3D: {reduced_3d.shape}")
#
# File ~/code/diorama/src/diorama/__init__.py:167, in reduce(embeddings, n_components, method, show_progress, **kwargs)
#     150 """Reduce high-dimensional embeddings to 2D or 3D.
#     151
#     152 Convenience function for caching the (expensive) reduction step.
#    (...)    163     (N, n_components) numpy array.
#     164 """
#     165 from diorama.reduction import reduce_embeddings
# --> 167 return reduce_embeddings(
#     168     embeddings, n_components=n_components, method=method, show_progress=show_progress, **kwargs
#     169 )
#
# File ~/code/diorama/src/diorama/reduction.py:46, in reduce_embeddings(embeddings, n_components, method, show_progress, **kwargs)
#      40     raise ValueError(
#      41         f"Cannot reduce {d}-dimensional embeddings to {n_components} dimensions. "
#      42         f"Input must have more dimensions than n_components."
#      43     )
#      45 if method == "umap":
# ---> 46     return _reduce_umap(embeddings, n_components, show_progress=show_progress, **kwargs)
#      47 elif method == "tsne":
#      48     return _reduce_tsne(embeddings, n_components, show_progress=show_progress, **kwargs)
#
# File ~/code/diorama/src/diorama/reduction.py:67, in _reduce_umap(embeddings, n_components, show_progress, **kwargs)
#      65 params = {**defaults, **kwargs, "n_components": n_components, "verbose": show_progress}
#      66 reducer = UMAP(**params)
# ---> 67 return reducer.fit_transform(embeddings)
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/umap_.py:2935, in UMAP.fit_transform(self, X, y, ensure_all_finite, **kwargs)
#    2897 def fit_transform(self, X, y=None, ensure_all_finite=True, **kwargs):
#    2898     """Fit X into an embedded space and return that transformed
#    2899     output.
#    2900
#    (...)   2933         Local radii of data points in the embedding (log-transformed).
#    2934     """
# -> 2935     self.fit(X, y, ensure_all_finite, **kwargs)
#    2936     if self.transform_mode == "embedding":
#    2937         if self.output_dens:
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/umap_.py:2817, in UMAP.fit(self, X, y, ensure_all_finite, **kwargs)
#    2813 if self.transform_mode == "embedding":
#    2814     epochs = (
#    2815         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2816     )
# -> 2817     self.embedding_, aux_data = self._fit_embed_data(
#    2818         self._raw_data[index],
#    2819         epochs,
#    2820         init,
#    2821         random_state,  # JH why raw data?
#    2822         **kwargs,
#    2823     )
#    2825     if self.n_epochs_list is not None:
#    2826         if "embedding_list" not in aux_data:
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/umap_.py:2872, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state, **kwargs)
#    2867 def _fit_embed_data(self, X, n_epochs, init, random_state, **kwargs):
#    2868     """A method wrapper for simplicial_set_embedding that can be
#    2869     replaced by subclasses. Arbitrary keyword arguments can be passed
#    2870     through .fit() and .fit_transform().
#    2871     """
# -> 2872     return simplicial_set_embedding(
#    2873         X,
#    2874         self.graph_,
#    2875         self.n_components,
#    2876         self._initial_alpha,
#    2877         self._a,
#    2878         self._b,
#    2879         self.repulsion_strength,
#    2880         self.negative_sample_rate,
#    2881         n_epochs,
#    2882         init,
#    2883         random_state,
#    2884         self._input_distance_func,
#    2885         self._metric_kwds,
#    2886         self.densmap,
#    2887         self._densmap_kwds,
#    2888         self.output_dens,
#    2889         self._output_distance_func,
#    2890         self._output_metric_kwds,
#    2891         self.output_metric in ("euclidean", "l2"),
#    2892         self.random_state is None,
#    2893         self.verbose,
#    2894         tqdm_kwds=self.tqdm_kwds,
#    2895     )
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/umap_.py:1109, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1105     embedding = noisy_scale_coords(
#    1106         embedding, random_state, max_coord=10, noise=0.0001
#    1107     )
#    1108 elif isinstance(init, str) and init == "spectral":
# -> 1109     embedding = spectral_layout(
#    1110         data,
#    1111         graph,
#    1112         n_components,
#    1113         random_state,
#    1114         metric=metric,
#    1115         metric_kwds=metric_kwds,
#    1116     )
#    1117     # We add a little noise to avoid local minima for optimization to come
#    1118     embedding = noisy_scale_coords(
#    1119         embedding, random_state, max_coord=10, noise=0.0001
#    1120     )
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/spectral.py:304, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds, tol, maxiter)
#     263 def spectral_layout(
#     264     data,
#     265     graph,
#    (...)    271     maxiter=0,
#     272 ):
#     273     """
#     274     Given a graph compute the spectral embedding of the graph. This is
#     275     simply the eigenvectors of the laplacian of the graph. Here we use the
#    (...)    302         The spectral embedding of the graph.
#     303     """
# --> 304     return _spectral_layout(
#     305         data=data,
#     306         graph=graph,
#     307         dim=dim,
#     308         random_state=random_state,
#     309         metric=metric,
#     310         metric_kwds=metric_kwds,
#     311         init="random",
#     312         tol=tol,
#     313         maxiter=maxiter,
#     314     )
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/spectral.py:467, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     464 n_components, labels = scipy.sparse.csgraph.connected_components(graph)
#     466 if n_components > 1:
# --> 467     return multi_component_layout(
#     468         data,
#     469         graph,
#     470         n_components,
#     471         labels,
#     472         dim,
#     473         random_state,
#     474         metric=metric,
#     475         metric_kwds=metric_kwds,
#     476     )
#     478 sqrt_deg = np.sqrt(np.asarray(graph.sum(axis=0)).squeeze())
#     479 # standard Laplacian
#     480 # D = scipy.sparse.spdiags(diag_data, 0, graph.shape[0], graph.shape[0])
#     481 # L = D - graph
#     482 # Normalized Laplacian
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/spectral.py:243, in multi_component_layout(data, graph, n_components, component_labels, dim, random_state, metric, metric_kwds, init, tol, maxiter)
#     234     result[component_labels == label] = (
#     235         random_state.uniform(
#     236             low=-data_range,
#    (...)    240         + meta_embedding[label]
#     241     )
#     242 else:
# --> 243     component_embedding = _spectral_layout(
#     244         data=None,
#     245         graph=component_graph,
#     246         dim=dim,
#     247         random_state=random_state,
#     248         metric=metric,
#     249         metric_kwds=metric_kwds,
#     250         init=init,
#     251         tol=tol,
#     252         maxiter=maxiter,
#     253     )
#     254     expansion = data_range / np.max(np.abs(component_embedding))
#     255     component_embedding *= expansion
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/umap/spectral.py:519, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     516 X[:, 0] = sqrt_deg / np.linalg.norm(sqrt_deg)
#     518 if method == "eigsh":
# --> 519     eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     520         L,
#     521         k,
#     522         which="SM",
#     523         ncv=num_lanczos_vectors,
#     524         tol=tol or 1e-4,
#     525         v0=np.ones(L.shape[0]),
#     526         maxiter=maxiter or graph.shape[0] * 5,
#     527     )
#     528 elif method == "lobpcg":
#     529     with warnings.catch_warnings():
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1778, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode, rng)
#    1773 params = _SymmetricArpackParams(n, k, A.dtype.char, matvec, mode,
#    1774                                 M_matvec, Minv_matvec, sigma,
#    1775                                 ncv, v0, maxiter, which, tol, rng)
#    1777 while not params.converged:
# -> 1778     params.iterate()
#    1780 return params.extract(return_eigenvectors)
#
# File ~/code/diorama/.venv/lib/python3.12/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:583, in _SymmetricArpackParams.iterate(self)
#     582 def iterate(self):
# --> 583     self._arpack_solver(self.arpack_dict, self.resid, self.v, self.ipntr,
#     584                         self.workd, self.workl)
#     586     xslice = slice(self.ipntr[0], self.ipntr[0] + self.n)
#     587     yslice = slice(self.ipntr[1], self.ipntr[1] + self.n)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Color by a single field

# %%
diorama.show(reduced_2d, documents, color_by="Make", height=1000)

# %% [markdown]
# ## 3D view

# %%
diorama.show(reduced_3d, documents, color_by="Make", height=800)

# %% [markdown]
# ## Dropdown with multiple coloring fields

# %%
diorama.show(reduced_2d, documents, color_by=["Make", "Body Type", "Color", "County", "Model Year"], height=800)

# %% [markdown]
# ## Continuous coloring
#
# `Unladen Weight` is numeric with many unique values — auto-detected as continuous.

# %%
diorama.show(reduced_2d, documents, color_by="Unladen Weight", height=800)

# %% [markdown]
# ## Filtering with MongoDB syntax
#
# Only show Tesla vehicles from 2024+.

# %%
diorama.show(
    reduced_2d, documents, color_by="Body Type", filter={"Make": "TESLA", "Model Year": {"$gte": 2024}}, height=800
)

# %% [markdown]
# ## Compare different filters
#
# Points stay in stable positions across filters since we pre-computed the reduction.

# %%
diorama.show(
    reduced_2d,
    documents,
    color_by="Make",
    filter={"County": {"$in": ["NASSAU", "SUFFOLK", "QUEENS", "KINGS"]}},
)

# %% [markdown]
# ## Auto-discover fields
#
# Pass `color_by=None` (default) to auto-discover the top fields by coverage.

# %%
diorama.show(reduced_2d, documents)

# %% [markdown]
# ## Dark mode

# %%
diorama.show(
    reduced_2d,
    documents,
    color_by="Make",
    color_scheme="dark",
)

# %% [markdown]
# ## Dash app
#
# Launch an interactive web UI with filter input, field dropdown, and 2D/3D toggle.
# Runs at http://127.0.0.1:8050 — stop the cell to shut it down.

# %%
diorama.app(embeddings, documents)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 diorama.app(embeddings, documents)
#
# TypeError: 'module' object is not callable
